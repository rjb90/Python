# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.plot([1, 2, 3], [5, 19, 14])

# %%
xs = np.linspace(0, 4 * np.pi, 200)
s = np.sin(xs)
c = np.cos(xs)

plt.plot(xs,s)
plt.plot(xs, c)

# %%
plt.plot([1, 2, 3, 4])
plt.ylabel('some number')
plt.xlabel('some other numbers')
# Out:
# Text(0.5,0,'some other numbers')

# %%
plt.plot([1,2,3,4],[1,4,9,16], 'ro')
plt.axis([0, 6, 0, 20])
# Out:
# [0, 6, 0, 20]

# %%
t = np.arange(0., 5., 0.2)
plt.plot(t, t, 'r--', t, t**2, 'bs', t, t**3, 'g^')
# Out:
# [<matplotlib.lines.Line2D at 0x7fb642c407b8>,
#  <matplotlib.lines.Line2D at 0x7fb642c40978>,
#  <matplotlib.lines.Line2D at 0x7fb642c391d0>]

# %%
plt.scatter(xs, c)
